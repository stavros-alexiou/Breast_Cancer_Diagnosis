# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/data.csv')

# %%
print(df.describe().T)
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
# Unnamed: 32                0.0           NaN           NaN          NaN
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
# Unnamed: 32                        NaN            NaN           NaN
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01
# Unnamed: 32                       NaN

# %%
# check for missing data

# %%
print(df.isnull().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
print(df.dtypes)
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# Unnamed: 32                float64
# dtype: object

# %%
sns.countplot(x='diagnosis', data=df)

# %%
# replace categorical values with numbers

# %%
print('Distribution of data: ', df['diagnosis'].value_counts())
# Out:
# Distribution of data:  B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# define the dependent variable that needs to be predicted (diagnosis)

# %%
y = df['diagnosis'].values

# %%
y
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'M', 'M', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'B'], dtype=object)

# %%
print('Labels before encoding are: ', np.unique(y))
# Out:
# Labels before encoding are:  ['B' 'M']

# %%
# encoding categorical data from text (B, M) to integers (0, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
Y = le.fit_transform(y)

# %%
print('Labels after encoding are: ', np.unique(Y))
# Out:
# Labels after encoding are:  [0 1]

# %%
# define and normalize/scale values

# %%
X = df.drop(['id', 'diagnosis', 'Unnamed: 32'], axis=1)

# %%
print(X.describe().T) #needs scaling
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# area_se                  569.0   40.337079   45.491006    6.802000
# smoothness_se            569.0    0.007041    0.003003    0.001713
# compactness_se           569.0    0.025478    0.017908    0.002252
# concavity_se             569.0    0.031894    0.030186    0.000000
# concave points_se        569.0    0.011796    0.006170    0.000000
# symmetry_se              569.0    0.020542    0.008266    0.007882
# fractal_dimension_se     569.0    0.003795    0.002646    0.000895
# radius_worst             569.0   16.269190    4.833242    7.930000
# texture_worst            569.0   25.677223    6.146258   12.020000
# perimeter_worst          569.0  107.261213   33.602542   50.410000
# area_worst               569.0  880.583128  569.356993  185.200000
# smoothness_worst         569.0    0.132369    0.022832    0.071170
# compactness_worst        569.0    0.254265    0.157336    0.027290
# concavity_worst          569.0    0.272188    0.208624    0.000000
# concave points_worst     569.0    0.114606    0.065732    0.000000
# symmetry_worst           569.0    0.290076    0.061867    0.156500
# fractal_dimension_worst  569.0    0.083946    0.018061    0.055040
#
#                                 25%         50%          75%         max
# radius_mean               11.700000   13.370000    15.780000    28.11000
# texture_mean              16.170000   18.840000    21.800000    39.28000
# perimeter_mean            75.170000   86.240000   104.100000   188.50000
# area_mean                420.300000  551.100000   782.700000  2501.00000
# smoothness_mean            0.086370    0.095870     0.105300     0.16340
# compactness_mean           0.064920    0.092630     0.130400     0.34540
# concavity_mean             0.029560    0.061540     0.130700     0.42680
# concave points_mean        0.020310    0.033500     0.074000     0.20120
# symmetry_mean              0.161900    0.179200     0.195700     0.30400
# fractal_dimension_mean     0.057700    0.061540     0.066120     0.09744
# radius_se                  0.232400    0.324200     0.478900     2.87300
# texture_se                 0.833900    1.108000     1.474000     4.88500
# perimeter_se               1.606000    2.287000     3.357000    21.98000
# area_se                   17.850000   24.530000    45.190000   542.20000
# smoothness_se              0.005169    0.006380     0.008146     0.03113
# compactness_se             0.013080    0.020450     0.032450     0.13540
# concavity_se               0.015090    0.025890     0.042050     0.39600
# concave points_se          0.007638    0.010930     0.014710     0.05279
# symmetry_se                0.015160    0.018730     0.023480     0.07895
# fractal_dimension_se       0.002248    0.003187     0.004558     0.02984
# radius_worst              13.010000   14.970000    18.790000    36.04000
# texture_worst             21.080000   25.410000    29.720000    49.54000
# perimeter_worst           84.110000   97.660000   125.400000   251.20000
# area_worst               515.300000  686.500000  1084.000000  4254.00000
# smoothness_worst           0.116600    0.131300     0.146000     0.22260
# compactness_worst          0.147200    0.211900     0.339100     1.05800
# concavity_worst            0.114500    0.226700     0.382900     1.25200
# concave points_worst       0.064930    0.099930     0.161400     0.29100
# symmetry_worst             0.250400    0.282200     0.317900     0.66380
# fractal_dimension_worst    0.071460    0.080040     0.092080     0.20750

# %%
# X needs scalling, bring everything in the same range

# %%
# scale/normalize the values to bring them to similar range

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
print(X)
# Out:
# [[0.52103744 0.0226581  0.54598853 ... 0.91202749 0.59846245 0.41886396]
#  [0.64314449 0.27257355 0.61578329 ... 0.63917526 0.23358959 0.22287813]
#  [0.60149557 0.3902604  0.59574321 ... 0.83505155 0.40370589 0.21343303]
#  ...
#  [0.45525108 0.62123774 0.44578813 ... 0.48728522 0.12872068 0.1519087 ]
#  [0.64456434 0.66351031 0.66553797 ... 0.91065292 0.49714173 0.45231536]
#  [0.03686876 0.50152181 0.02853984 ... 0.         0.25744136 0.10068215]]

# %%
# split data into training and testing to verify accuracy after fitting the model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=42)

# %%
# check the shape of the traing and testing data
print('Shape of training data is: ', X_train.shape) 
print('Shape of testing data is: ', X_test.shape)
# Out:
# Shape of training data is:  (512, 30)
# Shape of testing data is:  (57, 30)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

# %%
# defining the model
model = Sequential()
model.add(Dense(16, input_dim=30, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                496
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit the model with no-early stopping or other callbacks
# history is a dictionary to capture the loss and accuracy scores so i can plot later on
history = model.fit(X_train, Y_train, verbose=1, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 45ms/step - loss: 0.6640 - accuracy: 0.4375 - val_loss: 0.6653 - val_accuracy: 0.4035
# Epoch 2/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6477 - accuracy: 0.5215 - val_loss: 0.6477 - val_accuracy: 0.5263
# Epoch 3/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6331 - accuracy: 0.6504 - val_loss: 0.6297 - val_accuracy: 0.7544
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6303 - accuracy: 0.7090 - val_loss: 0.6123 - val_accuracy: 0.8596
# Epoch 5/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6115 - accuracy: 0.8008 - val_loss: 0.5983 - val_accuracy: 0.8772
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5967 - accuracy: 0.8340 - val_loss: 0.5841 - val_accuracy: 0.9298
# Epoch 7/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5921 - accuracy: 0.8359 - val_loss: 0.5710 - val_accuracy: 0.9298
# Epoch 8/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5774 - accuracy: 0.8711 - val_loss: 0.5575 - val_accuracy: 0.9474
# Epoch 9/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5706 - accuracy: 0.8477 - val_loss: 0.5458 - val_accuracy: 0.9649
# Epoch 10/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5581 - accuracy: 0.8887 - val_loss: 0.5342 - val_accuracy: 0.9649
# Epoch 11/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5521 - accuracy: 0.8555 - val_loss: 0.5221 - val_accuracy: 0.9649
# Epoch 12/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5389 - accuracy: 0.8477 - val_loss: 0.5093 - val_accuracy: 0.9649
# Epoch 13/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5236 - accuracy: 0.8496 - val_loss: 0.4965 - val_accuracy: 0.9649
# Epoch 14/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5216 - accuracy: 0.8535 - val_loss: 0.4824 - val_accuracy: 0.9474
# Epoch 15/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5160 - accuracy: 0.8613 - val_loss: 0.4718 - val_accuracy: 0.9649
# Epoch 16/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4924 - accuracy: 0.8848 - val_loss: 0.4607 - val_accuracy: 0.9649
# Epoch 17/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4829 - accuracy: 0.8887 - val_loss: 0.4490 - val_accuracy: 0.9649
# Epoch 18/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4773 - accuracy: 0.8867 - val_loss: 0.4376 - val_accuracy: 0.9649
# Epoch 19/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4745 - accuracy: 0.8711 - val_loss: 0.4257 - val_accuracy: 0.9649
# Epoch 20/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4579 - accuracy: 0.8887 - val_loss: 0.4130 - val_accuracy: 0.9649
# Epoch 21/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4563 - accuracy: 0.8770 - val_loss: 0.4017 - val_accuracy: 0.9825
# Epoch 22/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4434 - accuracy: 0.8809 - val_loss: 0.3938 - val_accuracy: 0.9825
# Epoch 23/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4340 - accuracy: 0.8984 - val_loss: 0.3838 - val_accuracy: 0.9825
# Epoch 24/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4179 - accuracy: 0.8984 - val_loss: 0.3728 - val_accuracy: 0.9825
# Epoch 25/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4189 - accuracy: 0.8828 - val_loss: 0.3629 - val_accuracy: 0.9649
# Epoch 26/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4105 - accuracy: 0.8848 - val_loss: 0.3527 - val_accuracy: 0.9649
# Epoch 27/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3992 - accuracy: 0.9023 - val_loss: 0.3447 - val_accuracy: 0.9649
# Epoch 28/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4009 - accuracy: 0.8867 - val_loss: 0.3351 - val_accuracy: 0.9649
# Epoch 29/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3900 - accuracy: 0.8809 - val_loss: 0.3273 - val_accuracy: 0.9649
# Epoch 30/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3752 - accuracy: 0.9023 - val_loss: 0.3200 - val_accuracy: 0.9649
# Epoch 31/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3798 - accuracy: 0.8828 - val_loss: 0.3121 - val_accuracy: 0.9649
# Epoch 32/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3655 - accuracy: 0.8965 - val_loss: 0.3063 - val_accuracy: 0.9825
# Epoch 33/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3512 - accuracy: 0.9023 - val_loss: 0.2987 - val_accuracy: 0.9825
# Epoch 34/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3542 - accuracy: 0.8828 - val_loss: 0.2909 - val_accuracy: 0.9649
# Epoch 35/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3444 - accuracy: 0.8945 - val_loss: 0.2842 - val_accuracy: 0.9649
# Epoch 36/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3446 - accuracy: 0.8906 - val_loss: 0.2781 - val_accuracy: 0.9649
# Epoch 37/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3203 - accuracy: 0.8984 - val_loss: 0.2717 - val_accuracy: 0.9649
# Epoch 38/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3241 - accuracy: 0.9062 - val_loss: 0.2658 - val_accuracy: 0.9649
# Epoch 39/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3281 - accuracy: 0.8906 - val_loss: 0.2598 - val_accuracy: 0.9649
# Epoch 40/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3254 - accuracy: 0.9023 - val_loss: 0.2551 - val_accuracy: 0.9649
# Epoch 41/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3145 - accuracy: 0.9082 - val_loss: 0.2503 - val_accuracy: 0.9825
# Epoch 42/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3191 - accuracy: 0.8926 - val_loss: 0.2472 - val_accuracy: 0.9825
# Epoch 43/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2933 - accuracy: 0.9141 - val_loss: 0.2408 - val_accuracy: 0.9825
# Epoch 44/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3100 - accuracy: 0.8926 - val_loss: 0.2348 - val_accuracy: 0.9649
# Epoch 45/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2928 - accuracy: 0.8926 - val_loss: 0.2298 - val_accuracy: 0.9649
# Epoch 46/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2928 - accuracy: 0.9121 - val_loss: 0.2254 - val_accuracy: 0.9649
# Epoch 47/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2859 - accuracy: 0.9160 - val_loss: 0.2217 - val_accuracy: 0.9649
# Epoch 48/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2870 - accuracy: 0.9062 - val_loss: 0.2184 - val_accuracy: 0.9825
# Epoch 49/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2774 - accuracy: 0.9102 - val_loss: 0.2135 - val_accuracy: 0.9649
# Epoch 50/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2826 - accuracy: 0.9062 - val_loss: 0.2092 - val_accuracy: 0.9649
# Epoch 51/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2790 - accuracy: 0.9023 - val_loss: 0.2060 - val_accuracy: 0.9825
# Epoch 52/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2792 - accuracy: 0.9043 - val_loss: 0.2038 - val_accuracy: 0.9825
# Epoch 53/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2613 - accuracy: 0.9121 - val_loss: 0.1999 - val_accuracy: 0.9825
# Epoch 54/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2664 - accuracy: 0.9258 - val_loss: 0.1961 - val_accuracy: 0.9825
# Epoch 55/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2596 - accuracy: 0.9199 - val_loss: 0.1925 - val_accuracy: 0.9825
# Epoch 56/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2514 - accuracy: 0.9219 - val_loss: 0.1890 - val_accuracy: 0.9825
# Epoch 57/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2678 - accuracy: 0.8945 - val_loss: 0.1860 - val_accuracy: 0.9825
# Epoch 58/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2437 - accuracy: 0.9277 - val_loss: 0.1823 - val_accuracy: 0.9825
# Epoch 59/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2460 - accuracy: 0.9121 - val_loss: 0.1808 - val_accuracy: 0.9825
# Epoch 60/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2463 - accuracy: 0.9199 - val_loss: 0.1782 - val_accuracy: 0.9825
# Epoch 61/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2396 - accuracy: 0.9160 - val_loss: 0.1733 - val_accuracy: 0.9825
# Epoch 62/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2277 - accuracy: 0.9141 - val_loss: 0.1701 - val_accuracy: 0.9825
# Epoch 63/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2302 - accuracy: 0.9316 - val_loss: 0.1683 - val_accuracy: 0.9825
# Epoch 64/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2464 - accuracy: 0.9023 - val_loss: 0.1659 - val_accuracy: 0.9825
# Epoch 65/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2260 - accuracy: 0.9180 - val_loss: 0.1643 - val_accuracy: 0.9825
# Epoch 66/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2343 - accuracy: 0.9219 - val_loss: 0.1616 - val_accuracy: 0.9825
# Epoch 67/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2176 - accuracy: 0.9375 - val_loss: 0.1587 - val_accuracy: 0.9825
# Epoch 68/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2306 - accuracy: 0.9141 - val_loss: 0.1565 - val_accuracy: 0.9825
# Epoch 69/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2272 - accuracy: 0.9336 - val_loss: 0.1549 - val_accuracy: 0.9825
# Epoch 70/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2178 - accuracy: 0.9199 - val_loss: 0.1533 - val_accuracy: 0.9825
# Epoch 71/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2204 - accuracy: 0.9395 - val_loss: 0.1508 - val_accuracy: 0.9825
# Epoch 72/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1999 - accuracy: 0.9355 - val_loss: 0.1485 - val_accuracy: 0.9649
# Epoch 73/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2043 - accuracy: 0.9355 - val_loss: 0.1465 - val_accuracy: 0.9649
# Epoch 74/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2130 - accuracy: 0.9219 - val_loss: 0.1450 - val_accuracy: 0.9825
# Epoch 75/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2069 - accuracy: 0.9258 - val_loss: 0.1435 - val_accuracy: 0.9825
# Epoch 76/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1994 - accuracy: 0.9375 - val_loss: 0.1422 - val_accuracy: 0.9825
# Epoch 77/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2070 - accuracy: 0.9355 - val_loss: 0.1400 - val_accuracy: 0.9649
# Epoch 78/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2037 - accuracy: 0.9258 - val_loss: 0.1381 - val_accuracy: 0.9649
# Epoch 79/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2055 - accuracy: 0.9277 - val_loss: 0.1372 - val_accuracy: 0.9649
# Epoch 80/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1897 - accuracy: 0.9297 - val_loss: 0.1369 - val_accuracy: 0.9825
# Epoch 81/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2007 - accuracy: 0.9238 - val_loss: 0.1351 - val_accuracy: 0.9649
# Epoch 82/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1859 - accuracy: 0.9375 - val_loss: 0.1330 - val_accuracy: 0.9649
# Epoch 83/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1958 - accuracy: 0.9297 - val_loss: 0.1312 - val_accuracy: 0.9649
# Epoch 84/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1804 - accuracy: 0.9512 - val_loss: 0.1305 - val_accuracy: 0.9649
# Epoch 85/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1766 - accuracy: 0.9434 - val_loss: 0.1290 - val_accuracy: 0.9649
# Epoch 86/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1810 - accuracy: 0.9473 - val_loss: 0.1275 - val_accuracy: 0.9649
# Epoch 87/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1772 - accuracy: 0.9434 - val_loss: 0.1258 - val_accuracy: 0.9649
# Epoch 88/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1842 - accuracy: 0.9336 - val_loss: 0.1251 - val_accuracy: 0.9649
# Epoch 89/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1807 - accuracy: 0.9434 - val_loss: 0.1247 - val_accuracy: 0.9649
# Epoch 90/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1672 - accuracy: 0.9512 - val_loss: 0.1228 - val_accuracy: 0.9649
# Epoch 91/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1787 - accuracy: 0.9395 - val_loss: 0.1214 - val_accuracy: 0.9649
# Epoch 92/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1865 - accuracy: 0.9375 - val_loss: 0.1208 - val_accuracy: 0.9649
# Epoch 93/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1761 - accuracy: 0.9492 - val_loss: 0.1198 - val_accuracy: 0.9649
# Epoch 94/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1854 - accuracy: 0.9355 - val_loss: 0.1188 - val_accuracy: 0.9649
# Epoch 95/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1682 - accuracy: 0.9375 - val_loss: 0.1178 - val_accuracy: 0.9649
# Epoch 96/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1614 - accuracy: 0.9473 - val_loss: 0.1170 - val_accuracy: 0.9649
# Epoch 97/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1669 - accuracy: 0.9570 - val_loss: 0.1168 - val_accuracy: 0.9649
# Epoch 98/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1721 - accuracy: 0.9375 - val_loss: 0.1151 - val_accuracy: 0.9649
# Epoch 99/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1738 - accuracy: 0.9355 - val_loss: 0.1143 - val_accuracy: 0.9649
# Epoch 100/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1637 - accuracy: 0.9531 - val_loss: 0.1138 - val_accuracy: 0.9649

# %%
# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Taining Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Taining Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Predicting the test set results

# %%
y_pred = model.predict(X_test)
print(y_pred)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[0.20184228]
#  [0.9974017 ]
#  [0.94656354]
#  [0.03038609]
#  [0.02778988]
#  [0.9999856 ]
#  [0.99996114]
#  [0.88839495]
#  [0.55972975]
#  [0.10691699]
#  [0.08287276]
#  [0.88094765]
#  [0.09407049]
#  [0.60848576]
#  [0.11679748]
#  [0.96624327]
#  [0.10459637]
#  [0.02126566]
#  [0.01370422]
#  [0.999153  ]
#  [0.4439924 ]
#  [0.05246155]
#  [0.9999217 ]
#  [0.04142762]
#  [0.04492506]
#  [0.03451757]
#  [0.16071494]
#  [0.03097649]
#  [0.05251753]
#  [0.99690825]
#  [0.03706216]
#  [0.07238958]
#  [0.01820871]
#  [0.09155753]
#  [0.02974846]
#  [0.05439501]
#  [0.5537177 ]
#  [0.06403157]
#  [0.9869017 ]
#  [0.14499497]
#  [0.02672312]
#  [0.87768906]
#  [0.09552639]
#  [0.06414904]
#  [0.06938934]
#  [0.10869534]
#  [0.01363526]
#  [0.0208615 ]
#  [0.09071334]
#  [0.15860674]
#  [0.9766913 ]
#  [0.99962926]
#  [0.3020201 ]
#  [0.06829012]
#  [0.02010315]
#  [0.23353268]
#  [0.02954818]]
# [[False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(Y_test, y_pred)
sns.heatmap(cm, annot=True)
